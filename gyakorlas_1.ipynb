# %%
# %%html
# <style>
# .question{
#     background: #99ffff;
#     border: solid 1px #1356ff;
#     border-radius: 3px;
#     padding: 2px;
# }
# .question>code {background: #e8ffff;border: solid 1px #83aab7;}
# .warning {background: #ffadad;}
# .Q{font-weight: bold;}
# </style>
# Out:
# <style>
# .question{
#     background: #99ffff;
#     border: solid 1px #1356ff;
#     border-radius: 3px;
#     padding: 2px;
# }
# .question>code {background: #e8ffff;border: solid 1px #83aab7;}
# .warning {background: #ffadad;}
# .Q{font-weight: bold;}
# </style>

# %% [markdown]
# 1. <font class="warning">A fenti cella tartalmát kérem ne módositsa!</font>
# 2. A kódcellákon belül csak a `## TODO ##` részt töltse ki.

# %% [markdown]
# # 1. házi feladat - vizualizáció

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# <p class="question"><span class="Q">1. feladat:</span> Olvassa be a <code>wine-quality.csv</code> adathalmazt, majd írassa ki a beolvasott fájl első 10 adatsorát!</p>

# %%
df = pd.read_csv('wine-quality.csv')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.6             0.400         0.32             1.7      0.035
# 1            5.2             0.240         0.15             7.1      0.043
# 2            8.9             0.840         0.34             1.4      0.050
# 3            5.8             0.330         0.23             5.0      0.053
# 4            7.1             0.360         0.24             1.8      0.025
# 5            7.1             0.130         0.29            15.5      0.064
# 6            7.2             0.170         0.34             6.4      0.042
# 7            7.4             0.660         0.00             1.8      0.075
# 8            6.2             0.220         0.27             1.5      0.064
# 9            5.4             0.835         0.08             1.2      0.046
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 39.0                  84.0  0.99096  3.59       0.48
# 1                 32.0                 134.0  0.99378  3.24       0.48
# 2                  4.0                  10.0  0.99554  3.12       0.48
# 3                 29.0                 106.0  0.99458  3.13       0.52
# 4                 32.0                 102.0  0.99030  3.34       0.59
# 5                 56.0                 115.5  0.99737  3.16       0.41
# 6                 16.0                 111.0  0.99278  2.99       0.40
# 7                 13.0                  40.0  0.99780  3.51       0.56
# 8                 20.0                 132.0  0.99380  3.22       0.46
# 9                 13.0                  93.0  0.99240  3.57       0.85
#
#    alcohol  quality   type
# 0     12.7        7  white
# 1      9.9        6  white
# 2      9.1        6    red
# 3      9.0        5  white
# 4     12.8        6  white
# 5      9.7        7  white
# 6     10.8        6  white
# 7      9.4        5    red
# 8      9.2        6  white
# 9     13.0        7    red

# %% [markdown]
# <p class="question"><span class="Q">2. feladat:</span> Hozzon létre egy új <code>red</code> adathalmazt, amely csak a vörös borok adatait tartalmazza! Írassa ki az új adathalmaz utolsó 5 adatsorát!</p>

# %%
red = df[df['type'] =='red']

# %%
red.head(5)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2             8.9             0.840         0.34             1.4      0.050
# 7             7.4             0.660         0.00             1.8      0.075
# 9             5.4             0.835         0.08             1.2      0.046
# 10            7.5             0.610         0.26             1.9      0.073
# 11            8.1             0.670         0.55             1.8      0.117
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                   4.0                  10.0  0.99554  3.12       0.48
# 7                  13.0                  40.0  0.99780  3.51       0.56
# 9                  13.0                  93.0  0.99240  3.57       0.85
# 10                 24.0                  88.0  0.99612  3.30       0.53
# 11                 32.0                 141.0  0.99680  3.17       0.62
#
#     alcohol  quality type
# 2       9.1        6  red
# 7       9.4        5  red
# 9      13.0        7  red
# 10      9.8        5  red
# 11      9.4        5  red

# %% [markdown]
# <p class="question"><span class="Q">3. feladat:</span> Rendezze csökkenő sorrendbe az eredeti <code>df</code> adathalmaz elemeit az <code>alcohol</code> oszlop értékei szerint! Ellenőrizze a sorrend helyességét az első 10 adatsor kiiratásával!</p>

# %%
df1 =  df.sort_values(by='alcohol')

# %%
df1.head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2137            4.2             0.215         0.23            5.10      0.041
# 6331            4.5             0.190         0.21            0.95      0.033
# 3123           10.4             0.610         0.49            2.10      0.200
# 6298            6.2             0.310         0.23            3.30      0.052
# 3006           14.3             0.310         0.74            1.80      0.075
# 507             6.4             0.370         0.12            5.90      0.056
# 2105            6.2             0.310         0.23            3.30      0.052
# 2093            6.5             0.180         0.48           18.00      0.054
# 1006            7.6             0.280         0.49           20.15      0.060
# 6349            7.8             0.180         0.46           12.60      0.042
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2137                 64.0                 157.0  0.99688  3.42       0.44
# 6331                 89.0                 159.0  0.99332  3.34       0.42
# 3123                  5.0                  16.0  0.99940  3.16       0.63
# 6298                 34.0                 113.0  0.99429  3.16       0.48
# 3006                  6.0                  15.0  1.00080  2.86       0.79
# 507                   6.0                  91.0  0.99536  3.06       0.46
# 2105                 34.0                 113.0  0.99429  3.16       0.48
# 2093                 56.0                 183.0  1.00038  2.98       0.61
# 1006                 30.0                 145.0  1.00196  3.01       0.44
# 6349                 41.0                 143.0  1.00000  3.24       0.76
#
#       alcohol  quality   type
# 2137      8.0        3  white
# 6331      8.0        5  white
# 3123      8.4        3    red
# 6298      8.4        5  white
# 3006      8.4        6    red
# 507       8.4        4  white
# 2105      8.4        5  white
# 2093      8.5        6  white
# 1006      8.5        5  white
# 6349      8.5        8  white

# %% [markdown]
# <p class="question"><span class="Q">4. feladat:</span> a.) Kérdezze le, hogy a <code>df</code> adathalmaz milyen minőségű borokból hányat tartalmaz a <code>quality</code> oszlop adatai alapján!
# b.) Válasszon egy megfelelő plotolási lehetőséget ezen adatok megjelenítésére!</p>

# %%
df['quality'].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='quality')
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %% [markdown]
# <p class="question"><span class="Q">5. feladat:</span> a.) Mutassa meg a vörös és fehér borok közötti különbséget a <code>df</code> adathalmaz <code>density</code> oszlop adatai alapján boxdiagramok alkalmazásával! b.) Végezzen el hasonló összehasonlítást a két bortípus között a <code>total sulfur dioxide</code> oszlop adatai alapján violinplot alkalmazásával!</p>

# %%
fig, ax = plt.subplots(figsize=(6, 3))
sns.boxplot(data=df, y="density",  x="type",ax=ax)
# Out:
# <Axes: xlabel='type', ylabel='density'>

# %%
plt.figure(figsize=(3,5))
sns.violinplot(data=df, x = "type", y= "total sulfur dioxide")
# Out:
# <Axes: xlabel='type', ylabel='total sulfur dioxide'>

# %% [markdown]
# <p class="question"><span class="Q">6. feladat:</span> Vizsgálja meg a <code>df</code> adathalmazban szereplő oszlopok közötti kapcsolatokat a korrelációs mátrixuk felhasználásával, melynek értékeit hőtérképen jelenítse meg!</p>

# %%
fig, ax = plt.subplots(figsize=(12,5))
corr = df.loc[:,:'quality'].corr()
sns.heatmap(corr,annot=True,ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# <p class="question"><span class="Q">7. feladat:</span> Vizsgálja meg a <code>df</code> adathalmazban szereplő <code>fixed acidity</code>, <code>density</code>, <code>total sulfur dioxide</code>, <code>alcohol</code>, <code>quality</code> és <code>pH</code> oszlopok közötti kapcsolatokat pairplot alkalmazásával, a <code>type</code> oszlop alapján a különböző bortípusokhoz tartozó adatokat különböző színnel megjelenítve!</p>

# %%
columns_to_plot = ['fixed acidity', 'density', 'total sulfur dioxide', 'alcohol', 'quality', 'pH', 'type']
sns.pairplot(df[columns_to_plot], hue='type', palette={'red': 'red', 'white': 'skyblue'})
plt.show()

# %% [markdown]
# <p class="question"><span class="Q">8. feladat</span> a.) Vizsgálja meg az <code>alcohol</code> és <code>density</code> oszlopok közötti kapcsolatot lineplot alkalmazásával! b.) Módosítsuk az előző megoldást, ha ugyanezt a kapcsolatot csak a jobb minőségű borokra szeretnénk megvizsgálni, ahol a <code>quality</code> oszlopban szereplő érték legalább 7.</p>

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='alcohol', y='density')
plt.title('Alkohol és sűrűség kapcsolata (Összes bor)')
plt.show()

# %%
high_quality_wines = df[df['quality'] >= 7]

plt.figure(figsize=(10, 6))
sns.lineplot(data=high_quality_wines, x='alcohol', y='density', color='green')
plt.title('Alkohol és sűrűség kapcsolata (Minőségi borok: Quality >= 7)')
plt.show()
